# %% [markdown]
# # Notebook for the Publisher Dimension
#
# This notebook displays the step taken to extract and clean/transform the table before the initial loading

# %%
import pandas as pd
path = 'C:\\Users\\Othamne\\Fundamentals-of-Data-Science-main\\Physical-Design-Deliverable-2\\Original data\\'

# %% [markdown]
# The data source doesn't provide the column names, so we manually add it

# %%
colnames = ["#", 'Name', 'Classification', 'Released_games', 'Unreleased_games', 'Total_revenue',
           'Avg_revenue_per_game', 'Med_revenue_per_game', '%_developed_in_house', '%_indie_releases',
           'Action', 'Casual', 'Adventure','Simaulation', 'Strategy', 'RPG', 'MMO', 'Racing', 'Sports']
Pub = pd.read_csv(path+"publisher.csv", header = 0, names=colnames)

# %%
Pub.head()
# Out:
#    #             Name Classification  Released_games  Unreleased_games  \
# 0  2          8Floor           Indie             282                 0
# 1  3            SEGA             AAA             231                 8
# 2  4  Strategy First           Indie             172                 1
# 3  5        HH-Games           Indie             160                 5
# 4  6         Ubisoft             AAA             158                 3
#
#   Total_revenue Avg_revenue_per_game Med_revenue_per_game  \
# 0         $8.3m              $29,257                 $485
# 1        $2.1bn                  $9m                $1.3m
# 2        $14.8m              $86,059              $10,883
# 3         $581k               $3,631               $1,607
# 4        $2.5bn               $15.7m                $1.5m
#
#   %_developed_in_house %_indie_releases Action Casual Adventure Simaulation  \
# 0                   7%               5%     0%   100%        7%          5%
# 1                  32%               5%    45%     7%       17%         14%
# 2                   6%              20%    18%    14%       27%         16%
# 3                   1%              57%    25%   100%       29%          7%
# 4                  12%               4%    58%     8%       34%         12%
#
#   Strategy  RPG MMO Racing Sports
# 0      15%   0%  1%     0%     0%
# 1      27%  13%  1%     5%    13%
# 2      35%   4%  0%     9%     2%
# 3      31%   1%  0%     0%     1%
# 4      16%  14%  2%    11%     6%

# %% [raw]
# We can already notice the type of transformation needed for this table:
# - Processing numerics
# - Droping the "#" columns

# %%
Pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     259 non-null    int64
#  1   Name                  259 non-null    object
#  2   Classification        259 non-null    object
#  3   Released_games        259 non-null    int64
#  4   Unreleased_games      259 non-null    int64
#  5   Total_revenue         259 non-null    object
#  6   Avg_revenue_per_game  259 non-null    object
#  7   Med_revenue_per_game  259 non-null    object
#  8   %_developed_in_house  259 non-null    object
#  9   %_indie_releases      259 non-null    object
#  10  Action                259 non-null    object
#  11  Casual                259 non-null    object
#  12  Adventure             259 non-null    object
#  13  Simaulation           259 non-null    object
#  14  Strategy              259 non-null    object
#  15  RPG                   259 non-null    object
#  16  MMO                   259 non-null    object
#  17  Racing                259 non-null    object
#  18  Sports                259 non-null    object
# dtypes: int64(3), object(16)
# memory usage: 38.6+ KB

# %% [markdown]
# There is no missing values but we still need to give the right type to each attribute

# %%
def o_to_f(x):
    t = x.replace(',','').replace('$','')#.replace('m','000000').replace('bn','000000000').replace('k','000')
    if 'm' in t:
        return float(t.replace('m','')) * 1000000
    elif 'bn' in t:
        return float(t.replace('bn','')) * 1000000000
    elif 'k' in t:
        return float(t.replace('k','')) * 1000
    else:
        return float(t)
    
def o_to_p(x):
    return float(x.replace('%',''))/100

Pub['Total_revenue'] = Pub['Total_revenue'].apply(lambda x: o_to_f(x))
Pub['Avg_revenue_per_game'] = Pub['Avg_revenue_per_game'].apply(lambda x: o_to_f(x))
Pub['Med_revenue_per_game'] = Pub['Med_revenue_per_game'].apply(lambda x: o_to_f(x)) 

Pub['%_developed_in_house'] = Pub['%_developed_in_house'].apply(lambda x: o_to_p(x))
Pub['%_indie_releases'] = Pub['%_indie_releases'].apply(lambda x: o_to_p(x))
Pub['Action'] = Pub['Action'].apply(lambda x: o_to_p(x))
Pub['Casual'] = Pub['Casual'].apply(lambda x: o_to_p(x))
Pub['Adventure'] = Pub['Adventure'].apply(lambda x: o_to_p(x))
Pub['Simaulation'] = Pub['Simaulation'].apply(lambda x: o_to_p(x))
Pub['Strategy'] = Pub['Strategy'].apply(lambda x: o_to_p(x))
Pub['RPG'] = Pub['RPG'].apply(lambda x: o_to_p(x))
Pub['MMO'] = Pub['MMO'].apply(lambda x: o_to_p(x))
Pub['Racing'] = Pub['Racing'].apply(lambda x: o_to_p(x))
Pub['Sports'] = Pub['Sports'].apply(lambda x: o_to_p(x))

# %% [markdown]
# Processing the numeric information so that they are in comformity before being staged

# %%
Pub.Name = Pub['Name'].astype(str)
Pub.Classification = Pub['Classification'].astype('category')

# %%
Pub = Pub.drop(columns='#')

# %% [markdown]
# We next deal with duplicate data to guarantee referencial integrity

# %%
Pub.loc[Pub.duplicated(keep="last"), :]
# Out:
#                          Name Classification  Released_games  \
# 76                 Meridian4           Indie              54
# 116            kovalevviktor           Indie              41
# 136              Curve Games           Indie              38
# 137            Aerosoft GmbH           Indie              38
# 155  Humongous Entertainment           Indie              35
# 156     Ratalaika Games S.L.           Indie              35
# 157             HIKARI FIELD           Indie              35
# 176               magnussoft           Indie              32
# 197                      KPL           Indie              29
# 215                JanduSoft           Indie              27
# 238   Twin Sails Interactive           Indie              25
#
#      Unreleased_games Total_revenue Avg_revenue_per_game Med_revenue_per_game  \
# 76                  5         $5.3m              $99,061               $9,341
# 116                 0         $131k               $3,193               $2,400
# 136                 4       $191.7m                  $5m                $463k
# 137                 6        $36.1m                $949k                $347k
# 155                 0         $1.4m              $38,939              $25,996
# 156                12         $287k               $8,202               $1,726
# 157                 3        $32.6m                $932k                $386k
# 176                 0       $19,410                 $607                 $240
# 197                 1         $2.8m              $97,978              $21,033
# 215                10         $208k               $7,690               $2,273
# 238                 4        $17.9m                $714k                $222k
#
#     %_developed_in_house %_indie_releases Action Casual Adventure Simaulation  \
# 76                    8%              97%    66%    41%       59%         10%
# 116                   5%              90%    12%    24%       51%         15%
# 136                   0%              81%    48%    17%       40%         31%
# 137                   0%              41%    14%    80%        5%         98%
# 155                 100%               0%     0%   100%       74%          0%
# 156                  21%             100%    72%    57%       51%          2%
# 157                   5%               0%     0%    74%       95%          5%
# 176                 100%               0%    22%    84%        0%         19%
# 197                   0%              63%    43%    37%       53%         13%
# 215                  27%              86%    65%    30%       59%         16%
# 238                  17%              38%    14%    45%       21%         14%
#
#     Strategy  RPG MMO Racing Sports
# 76       19%  22%  0%     5%     0%
# 116       0%   0%  0%     2%     5%
# 136      26%  10%  0%     5%    12%
# 137      18%   0%  0%     5%     2%
# 155       0%   0%  0%     0%     0%
# 156       6%   9%  0%     4%     0%
# 157       0%   0%  0%     0%     3%
# 176      31%   0%  0%    16%     9%
# 197      27%  20%  0%     3%     3%
# 215       8%  16%  0%     8%    14%
# 238      79%  24%  0%     0%     0%

# %%
Pub.loc[Pub.duplicated(keep="first"), :]
# Out:
#                          Name Classification  Released_games  \
# 79                 Meridian4           Indie              54
# 119            kovalevviktor           Indie              41
# 139              Curve Games           Indie              38
# 140            Aerosoft GmbH           Indie              38
# 159     Ratalaika Games S.L.           Indie              35
# 160             HIKARI FIELD           Indie              35
# 162  Humongous Entertainment           Indie              35
# 179               magnussoft           Indie              32
# 199                      KPL           Indie              29
# 219                JanduSoft           Indie              27
# 240   Twin Sails Interactive           Indie              25
#
#      Unreleased_games Total_revenue Avg_revenue_per_game Med_revenue_per_game  \
# 79                  5         $5.3m              $99,061               $9,341
# 119                 0         $131k               $3,193               $2,400
# 139                 4       $191.7m                  $5m                $463k
# 140                 6        $36.1m                $949k                $347k
# 159                12         $287k               $8,202               $1,726
# 160                 3        $32.6m                $932k                $386k
# 162                 0         $1.4m              $38,939              $25,996
# 179                 0       $19,410                 $607                 $240
# 199                 1         $2.8m              $97,978              $21,033
# 219                10         $208k               $7,690               $2,273
# 240                 4        $17.9m                $714k                $222k
#
#     %_developed_in_house %_indie_releases Action Casual Adventure Simaulation  \
# 79                    8%              97%    66%    41%       59%         10%
# 119                   5%              90%    12%    24%       51%         15%
# 139                   0%              81%    48%    17%       40%         31%
# 140                   0%              41%    14%    80%        5%         98%
# 159                  21%             100%    72%    57%       51%          2%
# 160                   5%               0%     0%    74%       95%          5%
# 162                 100%               0%     0%   100%       74%          0%
# 179                 100%               0%    22%    84%        0%         19%
# 199                   0%              63%    43%    37%       53%         13%
# 219                  27%              86%    65%    30%       59%         16%
# 240                  17%              38%    14%    45%       21%         14%
#
#     Strategy  RPG MMO Racing Sports
# 79       19%  22%  0%     5%     0%
# 119       0%   0%  0%     2%     5%
# 139      26%  10%  0%     5%    12%
# 140      18%   0%  0%     5%     2%
# 159       6%   9%  0%     4%     0%
# 160       0%   0%  0%     0%     3%
# 162       0%   0%  0%     0%     0%
# 179      31%   0%  0%    16%     9%
# 199      27%  20%  0%     3%     3%
# 219       8%  16%  0%     8%    14%
# 240      79%  24%  0%     0%     0%

# %% [markdown]
# The dupicates are similar we can delete them.

# %%
Pub.drop_duplicates(inplace=True)

# %%
Pub.to_csv(path+"Publisher-T.csv")
